# %%
#WE DONT HAVE THE PACKAGES SO IT WILL NOT RUN
# General python

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from datetime import datetime
from Weigfun import Weigfun
#from plateau import plateau
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# First, we need to build our model. You do this by coding in the following cells. Since we are working with a landscape-driven, semi-distributed model, we need to build each of the landscape units: plateau, hillslope and wetlands. We will start with the hillslope and wetland function. Since the plateau unit is more or less equivalent to the HBVmodel, the code structure is the same as the HVB model, and you do not have to code this part (it is already loaded in the first cell). After that, you can finalize the FlexTopo function. NOTE this is not written in BMI (yet).

# %%
#PLATEAU

def plateau_func(timestep, Par, forcing, Fluxes, States ):
	#HBVpareto Calculates values of 3 objective functions for HBV model

	Imax=Par[0]
	Ce=Par[1]
	Sumax=Par[2]
	beta=Par[3]
	Pmax=Par[4]
	Kf=Par[5]

	Qo = forcing['Q']
	Prec = forcing['prec']
	Etp = forcing['EP']


	tmax=len(Prec)
	Si=States[:,0]
	Su=States[:,1]
	Sf=States[:,2]

	Eidt=Fluxes[:,0]
	Eadt=Fluxes[:,1]
	Qfdt=Fluxes[:,2]
	Qusdt=Fluxes[:,3]

	dt=1
	t=timestep


	Pdt=Prec[t]*dt
	Epdt=Etp[t]*dt
	# Interception Reservoir
	if Pdt>0:
		Si[t]=Si[t]+Pdt
		Pedt=max(0,Si[t]-Imax)
		Si[t]=Si[t]-Pedt
		Eidt[t]=0
	else:
	# Evaporation only when there is no rainfall
		Pedt=0
		Eidt[t]=min(Epdt,Si[t])
		Si[t]=Si[t]-Eidt[t]

	if t<tmax-1:
		Si[t+1]=Si[t]


	# Unsaturated Reservoir
	if Pedt>0:
		rho=(Su[t]/Sumax)**beta            
		Su[t]=Su[t]+(1-rho)*Pedt
		Qufdt=rho*Pedt
	else:
		Qufdt=0

	# Transpiration
	Epdt=max(0,Epdt-Eidt[t])
	Eadt[t]=Epdt*(Su[t]/(Sumax*Ce))
	Eadt[t]=min(Eadt[t],Su[t])
	Su[t]=Su[t]-Eadt[t]

	# Percolation
	Qusdt=(Su[t]/Sumax)*Pmax*dt
	Su[t]=Su[t]-min(Qusdt,Su[t])
	if t<tmax-1:
		Su[t+1]=Su[t]

	# Fast Reservoir
	Sf[t]=Sf[t]+Qufdt
	Qfdt[t]= dt*Kf*Sf[t]
	Sf[t]=Sf[t]-min(Qfdt[t],Sf[t])
	if t<tmax-1:
		Sf[t+1]=Sf[t]
	    
	    

	#save output
	States[:,0]=Si
	States[:,1]=Su
	States[:,2]=Sf

	Fluxes[:,0]=Eidt
	Fluxes[:,1]=Eadt
	Fluxes[:,2]=Qfdt
	Fluxes[:,3]=Qusdt

	return(Fluxes, States)

# %%
#HILLSLOPE
def hillslope_func(timestep, Par, forcing, Fluxes, States):
	# HBVpareto Calculates values of 3 objective functions for HBV model

	I_max = Par[0]
	Ce = Par[1]
	Su_max = Par[2]
	beta = Par[3]
	D = Par[4]
	Kf = Par[5]
	Qo = forcing['Q']
	Prec = forcing['prec']
	Etp = forcing['EP']


	t_max = len(Prec)
	Si = States[:,0]
	Su = States[:,1]
	Sf = States[:,2]

	Ei_dt = Fluxes[:,0]
	Ea_dt = Fluxes[:,1]
	Qf_dt = Fluxes[:,2]
	Qus_dt = Fluxes[:,3]

	dt = 1
	i = timestep
	P_dt = Prec[i] * dt
	Ep_dt = Etp[i] * dt
    
	'''UPDATE'''
	# Interception Reservoir
	if P_dt > 0:
		Si[i] = Si[i] + P_dt*dt
		Pe_dt = np.maximum(0, (Si[i] - I_max) / dt)
		Si[i] = Si[i] - Pe_dt*dt
		Ei_dt[i] = 0
              
	else:
		Pe_dt = np.maximum(0, (Si[i] - I_max)/dt)
		Ei_dt[i] = np.minimum(Ep_dt, Si[i] / dt)
		Si[i] = Si[i] - Pe_dt*dt - Ei_dt[i]*dt      
	if i < t_max-1:
		Si[i+1] = Si[i]		  

	# Unsaturated Reservoir
	
	
	
	if Pe_dt > 0:
		Cr = (Su[i] / Su_max) ** beta
		Qiu_dt = (1 - Cr) * Pe_dt # flux from Ir to Ur
		Su[i] = Su[i] + Qiu_dt*dt
		Quf_dt = Cr * Pe_dt
	else:
		Quf_dt = 0

	# Transpiration
	Ep_dt = max(0, Ep_dt - Ei_dt[i])
	Ea_dt[i] = Ep_dt * (Su[i] / (Su_max * Ce))
	Ea_dt[i] = min(Su[i] / dt, Ea_dt[i])
	Su[i] = Su[i] - Ea_dt[i]*dt

	# Preferential Percolation
	Qus_dt = D * Quf_dt

	# Fast Reservoir
	Sf[i] = Sf[i] + (1-D) * Quf_dt
	Qf_dt[i] = dt * Kf * Sf[i]
	Sf[i] = Sf[i] - Qf_dt[i]*dt

	# Save output
	States[:,0] = Si
	States[:,1] = Su
	States[:,2] = Sf

	Fluxes[:,0] = Ei_dt
	Fluxes[:,1] = Ea_dt
	Fluxes[:,2] = Qf_dt
	Fluxes[:,3] = Qus_dt

	return(Fluxes, States)

# %%
#WETLANDS
def wetland_func(timestep, Par, forcing, Fluxes, States, Ss, landscape_per):
	# HBVpareto Calculates values of 3 objective functions for HBV model

	I_max = Par[0]
	Ce = Par[1]
	Su_max = Par[2]
	beta = Par[3]
	C_max = Par[4]
	Kf = Par[5]

	Qo = forcing['Q']
	Prec = forcing['prec']
	Etp = forcing['EP']


	t_max = len(Prec)
	Si = States[:,0]
	Su = States[:,1]
	Sf = States[:,2]

	Ei_dt = Fluxes[:,0]
	Ea_dt = Fluxes[:,1]
	Qf_dt = Fluxes[:,2]

	dt = 1
	i = timestep

	P_dt = Prec[i] * dt
	Ep_dt = Etp[i] * dt
	'''UPDATE'''
	# Interception Reservoir
	if P_dt > 0:
		Si[i] = Si[i] + P_dt*dt
		Pe_dt = np.maximum(0, (Si[i] - I_max) / dt)
		Si[i] = Si[i] - Pe_dt*dt
		Ei_dt[i] = 0
	else:
        # Evaporation only when there is no rainfall
		Pe_dt = np.maximum(0, (Si[i] - I_max) / dt) #is zero, because of no rainfall
		Ei_dt[i] = np.minimum(Ep_dt, Si[i] / dt)
		Si[i] = Si[i] - Pe_dt*dt - Ei_dt[i]*dt
	if i < t_max-1:
		Si[i+1] = Si[i]

	'''UPDATE'''
	# Unsaturated Reservoir

	if Pe_dt > 0:
		Cr = (Su[i] / Su_max) ** beta
		Qiu_dt = (1 - Cr) * Pe_dt # flux from Ir to Ur
		Su[i] = Su[i] + Qiu_dt*dt
		Quf_dt = Cr * Pe_dt #flux from Su to Sf
	else:
		Quf_dt = 0
	

	'''UPDATE'''
	# Transpiration
	Ep_dt = max(0, Ep_dt - Ei_dt[i])
	Ea_dt[i] = Ep_dt * (Su[i] / (Su_max * Ce))
	Ea_dt[i] = min(Su[i] / dt, Ea_dt[i])
	Su[i] = Su[i] - Ea_dt[i]*dt

	'''UPDATE'''
	# Capillary rise
	Qr_dt = (1-Su[i]/Su_max) * C_max
	Qr_dt = min(Qr_dt, Ss[i]*landscape_per/dt )#check if the groundwater has enough water (note: you need to use the landscape percentage!!!)

	if ((Su[i] + Qr_dt) > Su_max):
		Qr_dt = Su_max - Su[i]

	'''UPDATE'''
	Su[i] = Su[i] + Qr_dt*dt
	Ss[i] = Ss[i] - Qr_dt*dt * landscape_per

	if i < t_max - 1:
		Su[i+1] = Su[i]

	'''UPDATE'''
	# Fast Reservoir
	Sf[i] = Sf[i] + Quf_dt*dt
	Qf_dt = dt * Kf * Sf[i]
	Sf[i] = Sf[i] - Qf_dt*dt
	if i < t_max-1:
		Sf[i+1] = Sf[i]


	# Save output
	States[:,0] = Si
	States[:,1] = Su
	States[:,2] = Sf

	Fluxes[:,0] = Ei_dt
	Fluxes[:,1] = Ea_dt
	Fluxes[:,2] = Qf_dt

	return(Fluxes, States, Ss)

# %%
def FLEXtopo(ParPlateau, ParHillslope, ParWetland, ParCatchment, forcing, landscapes):

	# Parameters and constants
	T_lag = ParCatchment[1]
	Ks = ParCatchment[0]
	dt = 1
	t_max = len(forcing['Q'])

	# Initialize states
	States_plateau = np.zeros((t_max,3))
	States_hillslope = np.zeros((t_max,3))
	States_wetland = np.zeros((t_max,3))
	Ss = np.zeros((t_max,1))

	# Initialize fluxes
	Fluxes_plateau = np.zeros((t_max,4))
	Fluxes_hillslope = np.zeros((t_max,4))
	Fluxes_wetland = np.zeros((t_max,3))
	Qs_dt = np.zeros(t_max)
	Q_tot_dt = np.zeros(t_max)

	# Loop over time
	for t in range(0,t_max):

		# Plateau
		Fluxes_plateau, States_plateau = plateau_func(t, ParPlateau, forcing, Fluxes_plateau, States_plateau)
		# Hillslope
		Fluxes_hillslope, States_hillslope = hillslope_func(t, ParHillslope, forcing, Fluxes_hillslope, States_hillslope)

		# Wetland
		Fluxes_wetland, States_wetland, Ss = wetland_func(t, ParWetland, forcing, Fluxes_wetland, States_wetland, Ss, landscapes[2])

		# Slow Reservoir
		'''UPDATE'''
		Ss[t] = Ss[t] + Fluxes_plateau[t,3]*dt * landscapes[0] + Fluxes_hillslope[t,3]*dt * landscapes[1]
		Qs_dt = dt * Ks * Ss[t]
		Ss[t] = Ss[t] - min(Qs_dt,Ss[t])
		if t < t_max - 1:
			Ss[t+1] = Ss[t]

		'''UPDATE'''
		Q_tot_dt[t] = Qs_dt + Fluxes_plateau[t,2] * landscapes[0] + Fluxes_hillslope[t,2] * landscapes[1] +  Fluxes_wetland[t,2] * landscapes[2]

	# Offset Q
	weigths = Weigfun(T_lag)

	Qm = np.convolve(Q_tot_dt, weigths)
	Qm = Qm[0:t_max]

	return(Qm)

# %%
DEM = np.genfromtxt('dem.asc', skip_header=7,  dtype=float, autostrip=True)
slope = np.genfromtxt('slope.asc',skip_header=7,  dtype=float, autostrip=True)
hand = np.genfromtxt('hand_pos.asc', skip_header=7,  dtype=float, autostrip=True)
basin = np.genfromtxt('basin.asc',skip_header=7,  dtype=float, autostrip=True)

# %%
# plot DEM
plt.figure(1)
DEM[DEM==-99999]=np.nan
plt.imshow(DEM, cmap='hsv', label = 'DEM')
plt.title('DEM Jucar Basin')
plt.colorbar()

'''UPDATE'''
# plot HAND
plt.figure(2)
hand[hand==-9999]=np.nan
plt.imshow(hand, label = 'hand')
plt.colorbar()
plt.title('HAND Jucar Basin')
plt.legend()
plt.show()

# plot slope
plt.figure(3)
slope[slope==-9999]=np.nan
plt.imshow(slope, cmap='viridis', label = 'slope')
plt.title('Slope Jucar Basin')
plt.legend()
plt.colorbar()
plt.show()

# %%
'''UPDATE'''
# Make landscape classification
hillslope = np.array(slope) > 11
plateau = (np.array(hand) > 5) & (np.array(slope) <= 11)
wetland = (np.array(hand) <= 5) & (np.array(slope) <= 11)
basin = np.array(basin) > 0

'''UPDATE'''
hillslope_per = float(np.sum(hillslope))/float(np.sum(basin))
wetland_per = float(np.sum(wetland))/float(np.sum(basin))
plateau_per = float(np.sum(plateau))/float(np.sum(basin))

landscapes=np.zeros((8431,8871))
landscapes[plateau] = 1
landscapes[hillslope] = 2
landscapes[wetland] = 3

# Plot landscapes
cmap = mpl.colors.ListedColormap(['white', 'red', 'green', 'blue'])
bounds = [0, 1, 2, 3, 4]
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)

plt.figure(3)
plt.imshow(landscapes, cmap=cmap, norm=norm)
plt.colorbar()
plt.show()

# %%
import xarray as xr

experiment_start_time = "2000-01-01T00:00:00Z"
experiment_end_time = "2018-12-31T00:00:00Z"

filename = "OBS6_ERA5_reanaly_1_day_pr_2000-2018_newbasin.nc"  # Update the path to the correct location of the file
ds = xr.open_dataset(filename)
df = ds.to_dataframe()
df.reset_index(inplace=True)
df = df[df['bnds'] == 0]
df.index = pd.to_datetime(df['time'])
df.index = df.index.normalize()

df.drop(columns=['time', 'bnds'], inplace=True)
prec  = df['pr']  # Precipitation data
prec  = prec*86400  # Convert from m/s to mm/day)
prec[prec < 0] = 0  # Set negative values to zero
#print(prec.values)

filename = "Derived_Makkink_evspsblpot_newbasin.nc"  
dsEP = xr.open_dataset(filename)
dfEP = dsEP.to_dataframe()
dfEP.reset_index(inplace=True)
EP = dfEP['evspsblpot']  # Evapotranspiration data
EP.index = pd.to_datetime(dfEP['time'])
EP.index = EP.index.normalize()
EP = EP*86400  # Convert from mm/s to mm/day)
EP[EP < 0] = 0  # Set negative values to zero

filename = "Upstream_Q.txt"
Q = pd.read_csv(filename, delim_whitespace=True, index_col = 0, usecols =[0,4])
#date_mask = (Q.index >= experiment_start_time) & (Q.index <= experiment_end_time)
#print(Q.iloc[date_mask]/86400)
Q = Q.squeeze()
print(Q)

obs = pd.DataFrame({
    "Q": Q.values ,  # Discharge (converted from m³/day to m³/s)
    "prec": prec.values.flatten(),              # Precipitation
    "EP": EP.values.flatten()       # Potential evapotranspiration
})
obs.index = pd.to_datetime(Q.index)
obs.index.name = 'Time'


#obs = pd.DataFrame(Q.iloc[date_mask]/86400, df['pr'], dfEP['evspsblpot'])
#obs.columns = ["Q","prec", "EP"]
#obs.index.name = 'Time'
#obs.index = pd.to_datetime(obs.index)
obs.head()
# Out:
# Date
# 2000-01-01    0.000000
# 2000-01-02    0.082691
# 2000-01-03    0.079740
# 2000-01-04    0.077725
# 2000-01-05    0.073602
#                 ...
# 2018-12-27    0.058294
# 2018-12-28    0.054850
# 2018-12-29    0.055263
# 2018-12-30    0.055908
# 2018-12-31    0.058710
# Name: (m3/d), Length: 6940, dtype: float64
#                    Q      prec        EP
# Time
# 2000-01-01  0.000000  0.004437  1.156963
# 2000-01-02  0.082691  0.000000  1.175265
# 2000-01-03  0.079740  0.020500  1.067080
# 2000-01-04  0.077725  0.000000  1.165309
# 2000-01-05  0.073602  0.000000  1.169341

# %%
#      I_max Ce Su_max beta Pmax    Kf  
ParPlateau   = np.array([3.2, 0.50, 17.40, 0.95, 1.76, 0.91])   
                  #      I_max Ce Su_max beta D     Kf  
ParHillslope = np.array([3.25, 0.50, 321.99, 0.99, 0.4, 0.97])
                  #      I_max Ce Su_max beta C_max     Kf  
ParWetland   = np.array([9.94, 0.50, 53.25, 0.70, 0.65, 0.45])
              # Ks T_lag
ParCatchment = np.array([0.0281, 2.21])

'''UPDATE'''
# Landscape percentages
landscape_per = np.array([plateau_per, hillslope_per, wetland_per])

# %%
obs['Q'].max()
# Out:
# 0.6467453270599489

# %%
Qm = FLEXtopo(ParPlateau, ParHillslope, ParWetland, ParCatchment, obs, landscape_per)
Qo = obs['Q']#/86400 #m^3/s	

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(obs.index, Qo, label='Observed')
ax.plot(obs.index, Qm, label='Modelled')
ax.legend()
ax.set_title('Discharge - FLEXtopo')

ax.set_xlabel('Date')
ax.set_ylabel('Flow')
# Out:
# Text(0, 0.5, 'Flow')

# %%
from scipy.optimize import differential_evolution
from Weigfun import Weigfun  # Imported from notebook

# NSE calculation
def calculate_nse(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    return 1 - np.sum((obs[mask] - sim[mask])**2) / np.sum((obs[mask] - np.mean(obs[mask]))**2)

# logNSE calculation
def calculate_lognse(obs, sim):
    mask = (~np.isnan(obs)) & (~np.isnan(sim)) & (obs > 0) & (sim > 0)
    log_obs, log_sim = np.log(obs[mask]), np.log(sim[mask])
    return 1 - np.sum((log_obs - log_sim)**2) / np.sum((log_obs - np.mean(log_obs))**2)

def FLEXtopo(ParPlateau, ParHillslope, ParWetland, ParCatchment, forcing, landscapes):

	# Parameters and constants
	T_lag = ParCatchment[1]
	Ks = ParCatchment[0]
	dt = 1
	t_max = len(forcing['Q'])

	# Initialize states
	States_plateau = np.zeros((t_max,3))
	States_hillslope = np.zeros((t_max,3))
	States_wetland = np.zeros((t_max,3))
	Ss = np.zeros((t_max,1))

	# Initialize fluxes
	Fluxes_plateau = np.zeros((t_max,4))
	Fluxes_hillslope = np.zeros((t_max,4))
	Fluxes_wetland = np.zeros((t_max,3))
	Qs_dt = np.zeros(t_max)
	Q_tot_dt = np.zeros(t_max)

	# Loop over time
	for t in range(0,t_max):

		# Plateau
		Fluxes_plateau, States_plateau = plateau_func(t, ParPlateau, forcing, Fluxes_plateau, States_plateau)
		# Hillslope
		Fluxes_hillslope, States_hillslope = hillslope_func(t, ParHillslope, forcing, Fluxes_hillslope, States_hillslope)

		# Wetland
		Fluxes_wetland, States_wetland, Ss = wetland_func(t, ParWetland, forcing, Fluxes_wetland, States_wetland, Ss, landscapes[2])

		# Slow Reservoir
		'''UPDATE'''
		Ss[t] = Ss[t] + Fluxes_plateau[t,3]*dt * landscapes[0] + Fluxes_hillslope[t,3]*dt * landscapes[1]
		Qs_dt = dt * Ks * Ss[t]
		Ss[t] = Ss[t] - min(Qs_dt,Ss[t])
		if t < t_max - 1:
			Ss[t+1] = Ss[t]

		'''UPDATE'''
		Q_tot_dt[t] = Qs_dt + Fluxes_plateau[t,2] * landscapes[0] + Fluxes_hillslope[t,2] * landscapes[1] +  Fluxes_wetland[t,2] * landscapes[2]

	# Offset Q
	weigths = Weigfun(T_lag)

	Qm = np.convolve(Q_tot_dt, weigths)
	Qm = Qm[0:t_max]

	return(Qm)


# Calibration function
def calibrate_flextopo(forcing_data, landscapes, param_bounds, nse_weight=0.5):
    observed = forcing_data['Q'].values if hasattr(forcing_data['Q'], 'values') else forcing_data['Q']
    counter = {'runs': 0}


    def objective(params):
        counter['runs'] += 1
        print(f"→ Model evaluation #{counter['runs']}")
        n = 6
        ParPlateau = params[0:n]
        ParHillslope = params[n:2*n]
        ParWetland = params[2*n:3*n]
        ParCatchment = params[3*n:]
        simulated = FLEXtopo(ParPlateau, ParHillslope, ParWetland, ParCatchment, forcing_data, landscapes)

        if np.any(np.isnan(simulated)) or np.any(np.isinf(simulated)):
            print("⚠️ Simulated streamflow contains NaN or inf → penalizing solution")
            return 1e6  # Big penalty for bad simulation


        numerator_nse = np.sum((observed - simulated)**2)
        denominator_nse = np.sum((observed - observed.mean())**2)
        nse = 1 - (numerator_nse / denominator_nse)
        valid_log_mask = (observed > 0) & (simulated > 0)
        log_obs = np.log(observed[valid_log_mask])
        log_model = np.log(simulated[valid_log_mask])
        if len(log_obs) > 0:  # Only compute if valid data exists
               log_obs_mean = log_obs.mean()
               numerator_log_nse = np.sum((log_obs - log_model)**2)
               denominator_log_nse = np.sum((log_obs - log_obs_mean)**2)
               log_nse = 1 - (numerator_log_nse / denominator_log_nse)
        else:
               log_nse = -np.inf  # Penalize invalid cases

               
        if np.isnan(log_nse) or np.isinf(log_nse):
            print("⚠️ logNSE is NaN or inf → penalizing")
            return 1e6      
		
        #nse = calculate_nse(observed, simulated)
        #lognse = calculate_lognse(observed, simulated)
        return 1 - (nse_weight * nse + (1 - nse_weight) * log_nse)

    bounds = (
        param_bounds['Plateau'] +
        param_bounds['Hillslope'] +
        param_bounds['Wetland'] +
        param_bounds['Catchment']
    )

    result = differential_evolution(objective, bounds, strategy='best1bin',
                                    maxiter=10, popsize=10, tol=0.1,
                                    mutation=(0.5, 1), recombination=0.7) #,  workers=-1)

    opt = result.x
    return {
        'ParPlateau': opt[0:6],
        'ParHillslope': opt[6:12],
        'ParWetland': opt[12:18],
        'ParCatchment': opt[18:]
    }

# %%
forcing_data = {
    'prec': obs['prec'],
    'EP': obs['EP'],
    'Q': obs['Q']
}

landscapes = landscape_per 

param_bounds = {
    'Plateau': [(0, 100), (0.1, 2), (0, 500), (0.1, 5), (0, 20), (0, 1)],
    'Hillslope': [(0, 100), (0.1, 2), (0, 500), (0.1, 5), (0, 1), (0, 1)],
    'Wetland': [(0, 100), (0.1, 2), (0, 500), (0.1, 5), (0, 20), (0, 1)],
    'Catchment': [(0, 1), (0, 10)]
}

optimized_params = calibrate_flextopo(forcing_data, landscapes, param_bounds)

for k, v in optimized_params.items():
    print(f"{k}: {v}")
# Out:
# → Model evaluation #1
# → Model evaluation #2
# → Model evaluation #3
# → Model evaluation #4
# → Model evaluation #5
# → Model evaluation #6
# → Model evaluation #7
# → Model evaluation #8
# → Model evaluation #9
# → Model evaluation #10
# → Model evaluation #11
# → Model evaluation #12
# → Model evaluation #13
# → Model evaluation #14
# → Model evaluation #15
# → Model evaluation #16
# → Model evaluation #17
# → Model evaluation #18
# → Model evaluation #19
# → Model evaluation #20
# → Model evaluation #21
# → Model evaluation #22
# → Model evaluation #23
# → Model evaluation #24
# → Model evaluation #25
# → Model evaluation #26
# → Model evaluation #27
# → Model evaluation #28
# → Model evaluation #29
# → Model evaluation #30
# → Model evaluation #31
# → Model evaluation #32
# → Model evaluation #33
# → Model evaluation #34
# → Model evaluation #35
# → Model evaluation #36
# → Model evaluation #37
# → Model evaluation #38
# → Model evaluation #39
# → Model evaluation #40
# → Model evaluation #41
# ⚠️ Simulated streamflow contains NaN or inf → penalizing solution
# → Model evaluation #42
# → Model evaluation #43
# → Model evaluation #44
# → Model evaluation #45
# → Model evaluation #46
# → Model evaluation #47
# → Model evaluation #48
# → Model evaluation #49
# → Model evaluation #50
# → Model evaluation #51
# → Model evaluation #52
# → Model evaluation #53
# → Model evaluation #54
# → Model evaluation #55
# → Model evaluation #56
# → Model evaluation #57
# → Model evaluation #58
# → Model evaluation #59
# → Model evaluation #60
# → Model evaluation #61
# → Model evaluation #62
# → Model evaluation #63
# → Model evaluation #64
# → Model evaluation #65
# → Model evaluation #66
# → Model evaluation #67
# → Model evaluation #68
# → Model evaluation #69
# → Model evaluation #70
# → Model evaluation #71
# → Model evaluation #72
# → Model evaluation #73
# → Model evaluation #74
# → Model evaluation #75
# → Model evaluation #76
# → Model evaluation #77
# → Model evaluation #78
# → Model evaluation #79
# → Model evaluation #80
# → Model evaluation #81
# → Model evaluation #82
# → Model evaluation #83
# → Model evaluation #84
# → Model evaluation #85
# → Model evaluation #86
# → Model evaluation #87
# → Model evaluation #88
# → Model evaluation #89
# → Model evaluation #90
# → Model evaluation #91
# → Model evaluation #92
# → Model evaluation #93
# → Model evaluation #94
# → Model evaluation #95
# → Model evaluation #96
# → Model evaluation #97
# → Model evaluation #98
# → Model evaluation #99
# → Model evaluation #100
# → Model evaluation #101
# → Model evaluation #102
# → Model evaluation #103
# → Model evaluation #104
# → Model evaluation #105
# → Model evaluation #106
# → Model evaluation #107
# → Model evaluation #108
# → Model evaluation #109
# → Model evaluation #110
# → Model evaluation #111
# → Model evaluation #112
# → Model evaluation #113
# → Model evaluation #114
# → Model evaluation #115
# → Model evaluation #116
# → Model evaluation #117
# → Model evaluation #118
# → Model evaluation #119
# → Model evaluation #120
# → Model evaluation #121
# → Model evaluation #122
# → Model evaluation #123
# → Model evaluation #124
# → Model evaluation #125
# → Model evaluation #126
# → Model evaluation #127
# → Model evaluation #128
# → Model evaluation #129
# → Model evaluation #130
# → Model evaluation #131
# → Model evaluation #132
# → Model evaluation #133
# → Model evaluation #134
# → Model evaluation #135
# → Model evaluation #136
# → Model evaluation #137
# → Model evaluation #138
# → Model evaluation #139
# → Model evaluation #140
# → Model evaluation #141
# → Model evaluation #142
# → Model evaluation #143
# → Model evaluation #144
# → Model evaluation #145
# → Model evaluation #146
# → Model evaluation #147
# → Model evaluation #148
# → Model evaluation #149
# → Model evaluation #150
# → Model evaluation #151
# → Model evaluation #152
# → Model evaluation #153
# → Model evaluation #154
# → Model evaluation #155
# → Model evaluation #156
# → Model evaluation #157
# → Model evaluation #158
# → Model evaluation #159
# → Model evaluation #160
# → Model evaluation #161
# → Model evaluation #162
# → Model evaluation #163
# → Model evaluation #164
# → Model evaluation #165
# → Model evaluation #166
# → Model evaluation #167
# → Model evaluation #168
# → Model evaluation #169
# → Model evaluation #170
# → Model evaluation #171
# → Model evaluation #172
# → Model evaluation #173
# → Model evaluation #174
# → Model evaluation #175
# → Model evaluation #176
# → Model evaluation #177
# → Model evaluation #178
# → Model evaluation #179
# → Model evaluation #180
# → Model evaluation #181
# → Model evaluation #182
# ⚠️ Simulated streamflow contains NaN or inf → penalizing solution
# → Model evaluation #183
# → Model evaluation #184
# → Model evaluation #185
# → Model evaluation #186
# → Model evaluation #187
# → Model evaluation #188
# → Model evaluation #189
# → Model evaluation #190
# → Model evaluation #191
# → Model evaluation #192
# → Model evaluation #193
# → Model evaluation #194
# → Model evaluation #195
# → Model evaluation #196
# → Model evaluation #197
# → Model evaluation #198
# → Model evaluation #199
# → Model evaluation #200
# → Model evaluation #201
# → Model evaluation #202
# → Model evaluation #203
# → Model evaluation #204
# → Model evaluation #205
# → Model evaluation #206
# → Model evaluation #207
# → Model evaluation #208
# → Model evaluation #209
# → Model evaluation #210
# → Model evaluation #211
# → Model evaluation #212
# → Model evaluation #213
# → Model evaluation #214
# → Model evaluation #215
# → Model evaluation #216
# → Model evaluation #217
# → Model evaluation #218
# → Model evaluation #219
# → Model evaluation #220
# → Model evaluation #221
# → Model evaluation #222
# → Model evaluation #223
# → Model evaluation #224
# → Model evaluation #225
# → Model evaluation #226
# → Model evaluation #227
# → Model evaluation #228
# → Model evaluation #229
# → Model evaluation #230
# → Model evaluation #231
# → Model evaluation #232
# → Model evaluation #233
# → Model evaluation #234
# → Model evaluation #235
# → Model evaluation #236
# → Model evaluation #237
# → Model evaluation #238
# → Model evaluation #239
# → Model evaluation #240
# → Model evaluation #241
# → Model evaluation #242
# → Model evaluation #243
# → Model evaluation #244
# → Model evaluation #245
# → Model evaluation #246
# → Model evaluation #247
# → Model evaluation #248
# → Model evaluation #249
# → Model evaluation #250
# → Model evaluation #251
# → Model evaluation #252
# → Model evaluation #253
# → Model evaluation #254
# → Model evaluation #255
# → Model evaluation #256
# → Model evaluation #257
# → Model evaluation #258
# → Model evaluation #259
# → Model evaluation #260
# → Model evaluation #261
# → Model evaluation #262
# → Model evaluation #263
# → Model evaluation #264
# → Model evaluation #265
# → Model evaluation #266
# → Model evaluation #267
# → Model evaluation #268
# → Model evaluation #269
# → Model evaluation #270
# → Model evaluation #271
# → Model evaluation #272
# → Model evaluation #273
# → Model evaluation #274
# → Model evaluation #275
# → Model evaluation #276
# → Model evaluation #277
# → Model evaluation #278
# → Model evaluation #279
# → Model evaluation #280
# → Model evaluation #281
# → Model evaluation #282
# → Model evaluation #283
# → Model evaluation #284
# → Model evaluation #285
# → Model evaluation #286
# → Model evaluation #287
# → Model evaluation #288
# → Model evaluation #289
# → Model evaluation #290
# → Model evaluation #291
# → Model evaluation #292
# → Model evaluation #293
# → Model evaluation #294
# → Model evaluation #295
# → Model evaluation #296
# → Model evaluation #297
# → Model evaluation #298
# → Model evaluation #299
# → Model evaluation #300
# → Model evaluation #301
# → Model evaluation #302
# → Model evaluation #303
# → Model evaluation #304
# → Model evaluation #305
# → Model evaluation #306
# → Model evaluation #307
# → Model evaluation #308
# → Model evaluation #309
# → Model evaluation #310
# → Model evaluation #311
# → Model evaluation #312
# → Model evaluation #313
# → Model evaluation #314
# → Model evaluation #315
# → Model evaluation #316
# → Model evaluation #317
# → Model evaluation #318
# → Model evaluation #319
# → Model evaluation #320
# → Model evaluation #321
# → Model evaluation #322
# → Model evaluation #323
# → Model evaluation #324
# → Model evaluation #325
# → Model evaluation #326
# → Model evaluation #327
# → Model evaluation #328
# → Model evaluation #329
# → Model evaluation #330
# → Model evaluation #331
# → Model evaluation #332
# → Model evaluation #333
# → Model evaluation #334
# → Model evaluation #335
# → Model evaluation #336
# → Model evaluation #337
# → Model evaluation #338
# → Model evaluation #339
# → Model evaluation #340
# → Model evaluation #341
# → Model evaluation #342
# → Model evaluation #343
# → Model evaluation #344
# → Model evaluation #345
# → Model evaluation #346
# → Model evaluation #347
# → Model evaluation #348
# → Model evaluation #349
# → Model evaluation #350
# → Model evaluation #351
# → Model evaluation #352
# → Model evaluation #353
# → Model evaluation #354
# → Model evaluation #355
# → Model evaluation #356
# → Model evaluation #357
# → Model evaluation #358
# → Model evaluation #359
# → Model evaluation #360
# → Model evaluation #361
# → Model evaluation #362
# → Model evaluation #363
# → Model evaluation #364
# → Model evaluation #365
# → Model evaluation #366
# → Model evaluation #367
# → Model evaluation #368
# → Model evaluation #369
# → Model evaluation #370
# → Model evaluation #371
# → Model evaluation #372
# → Model evaluation #373
# → Model evaluation #374
# → Model evaluation #375
# → Model evaluation #376
# → Model evaluation #377
# → Model evaluation #378
# → Model evaluation #379
# → Model evaluation #380
# → Model evaluation #381
# → Model evaluation #382
# → Model evaluation #383
# → Model evaluation #384
# → Model evaluation #385
# → Model evaluation #386
# → Model evaluation #387
# → Model evaluation #388
# → Model evaluation #389
# → Model evaluation #390
# → Model evaluation #391
# → Model evaluation #392
# → Model evaluation #393
# → Model evaluation #394
# → Model evaluation #395
# → Model evaluation #396
# → Model evaluation #397
# → Model evaluation #398
# → Model evaluation #399
# → Model evaluation #400
# → Model evaluation #401
# → Model evaluation #402
# → Model evaluation #403
# → Model evaluation #404
# → Model evaluation #405
# → Model evaluation #406
# → Model evaluation #407
# → Model evaluation #408
# → Model evaluation #409
# → Model evaluation #410
# → Model evaluation #411
# → Model evaluation #412
# → Model evaluation #413
# → Model evaluation #414
# → Model evaluation #415
# → Model evaluation #416
# → Model evaluation #417
# → Model evaluation #418
# → Model evaluation #419
# → Model evaluation #420
# → Model evaluation #421
# → Model evaluation #422
# → Model evaluation #423
# → Model evaluation #424
# → Model evaluation #425
# → Model evaluation #426
# → Model evaluation #427
# → Model evaluation #428
# → Model evaluation #429
# → Model evaluation #430
# → Model evaluation #431
# → Model evaluation #432
# → Model evaluation #433
# → Model evaluation #434
# → Model evaluation #435
# → Model evaluation #436
# → Model evaluation #437
# → Model evaluation #438
# → Model evaluation #439
# → Model evaluation #440
# ⚠️ Simulated streamflow contains NaN or inf → penalizing solution
# → Model evaluation #441
# → Model evaluation #442
# → Model evaluation #443
# → Model evaluation #444
# → Model evaluation #445
# → Model evaluation #446
# → Model evaluation #447
# → Model evaluation #448
# → Model evaluation #449
# → Model evaluation #450
# → Model evaluation #451
# → Model evaluation #452
# → Model evaluation #453
# → Model evaluation #454
# → Model evaluation #455
# → Model evaluation #456
# → Model evaluation #457
# → Model evaluation #458
# → Model evaluation #459
# → Model evaluation #460
# → Model evaluation #461
# → Model evaluation #462
# → Model evaluation #463
# → Model evaluation #464
# → Model evaluation #465
# → Model evaluation #466
# → Model evaluation #467
# → Model evaluation #468
# → Model evaluation #469
# → Model evaluation #470
# → Model evaluation #471
# → Model evaluation #472
# → Model evaluation #473
# → Model evaluation #474
# → Model evaluation #475
# → Model evaluation #476
# → Model evaluation #477
# → Model evaluation #478
# → Model evaluation #479
# → Model evaluation #480
# → Model evaluation #481
# → Model evaluation #482
# → Model evaluation #483
# → Model evaluation #484
# → Model evaluation #485
# → Model evaluation #486
# → Model evaluation #487
# → Model evaluation #488
# → Model evaluation #489
# → Model evaluation #490
# → Model evaluation #491
# → Model evaluation #492
# → Model evaluation #493
# → Model evaluation #494
# → Model evaluation #495
# → Model evaluation #496
# → Model evaluation #497
# → Model evaluation #498
# → Model evaluation #499
# → Model evaluation #500
# → Model evaluation #501
# → Model evaluation #502
# → Model evaluation #503
# → Model evaluation #504
# → Model evaluation #505
# → Model evaluation #506
# → Model evaluation #507
# → Model evaluation #508
# → Model evaluation #509
# → Model evaluation #510
# → Model evaluation #511
# → Model evaluation #512
# → Model evaluation #513
# → Model evaluation #514
# → Model evaluation #515
# → Model evaluation #516
# → Model evaluation #517
# → Model evaluation #518
# → Model evaluation #519
# → Model evaluation #520
# → Model evaluation #521
# → Model evaluation #522
# → Model evaluation #523
# → Model evaluation #524
# → Model evaluation #525
# → Model evaluation #526
# → Model evaluation #527
# → Model evaluation #528
# → Model evaluation #529
# → Model evaluation #530
# → Model evaluation #531
# → Model evaluation #532
# → Model evaluation #533
# → Model evaluation #534
# → Model evaluation #535
# → Model evaluation #536
# → Model evaluation #537
# → Model evaluation #538
# → Model evaluation #539
# → Model evaluation #540
# → Model evaluation #541
# → Model evaluation #542
# → Model evaluation #543
# → Model evaluation #544
# → Model evaluation #545
# → Model evaluation #546
# → Model evaluation #547
# → Model evaluation #548
# → Model evaluation #549
# → Model evaluation #550
# → Model evaluation #551
# → Model evaluation #552
# → Model evaluation #553
# → Model evaluation #554
# → Model evaluation #555
# → Model evaluation #556
# → Model evaluation #557
# → Model evaluation #558
# → Model evaluation #559
# → Model evaluation #560
# → Model evaluation #561
# → Model evaluation #562
# → Model evaluation #563
# → Model evaluation #564
# → Model evaluation #565
# → Model evaluation #566
# → Model evaluation #567
# → Model evaluation #568
# → Model evaluation #569
# → Model evaluation #570
# → Model evaluation #571
# → Model evaluation #572
# → Model evaluation #573
# → Model evaluation #574
# → Model evaluation #575
# → Model evaluation #576
# → Model evaluation #577
# → Model evaluation #578
# → Model evaluation #579
# → Model evaluation #580
# → Model evaluation #581
# → Model evaluation #582
# → Model evaluation #583
# → Model evaluation #584
# → Model evaluation #585
# → Model evaluation #586
# → Model evaluation #587
# → Model evaluation #588
# → Model evaluation #589
# → Model evaluation #590
# → Model evaluation #591
# → Model evaluation #592
# → Model evaluation #593
# → Model evaluation #594
# → Model evaluation #595
# → Model evaluation #596
# → Model evaluation #597
# → Model evaluation #598
# → Model evaluation #599
# → Model evaluation #600
# → Model evaluation #601
# → Model evaluation #602
# → Model evaluation #603
# → Model evaluation #604
# → Model evaluation #605
# → Model evaluation #606
# → Model evaluation #607
# → Model evaluation #608
# → Model evaluation #609
# → Model evaluation #610
# → Model evaluation #611
# → Model evaluation #612
# → Model evaluation #613
# → Model evaluation #614
# → Model evaluation #615
# → Model evaluation #616
# → Model evaluation #617
# → Model evaluation #618
# → Model evaluation #619
# → Model evaluation #620
# → Model evaluation #621
# → Model evaluation #622
# → Model evaluation #623
# → Model evaluation #624
# → Model evaluation #625
# → Model evaluation #626
# → Model evaluation #627
# → Model evaluation #628
# → Model evaluation #629
# → Model evaluation #630
# → Model evaluation #631
# → Model evaluation #632
# → Model evaluation #633
# → Model evaluation #634
# → Model evaluation #635
# → Model evaluation #636
# → Model evaluation #637
# → Model evaluation #638
# → Model evaluation #639
# → Model evaluation #640
# → Model evaluation #641
# → Model evaluation #642
# → Model evaluation #643
# → Model evaluation #644
# → Model evaluation #645
# → Model evaluation #646
# → Model evaluation #647
# → Model evaluation #648
# → Model evaluation #649
# → Model evaluation #650
# → Model evaluation #651
# → Model evaluation #652
# → Model evaluation #653
# → Model evaluation #654
# → Model evaluation #655
# → Model evaluation #656
# → Model evaluation #657
# → Model evaluation #658
# → Model evaluation #659
# → Model evaluation #660
# → Model evaluation #661
# → Model evaluation #662
# → Model evaluation #663
# → Model evaluation #664
# → Model evaluation #665
# → Model evaluation #666
# → Model evaluation #667
# → Model evaluation #668
# → Model evaluation #669
# → Model evaluation #670
# → Model evaluation #671
# → Model evaluation #672
# → Model evaluation #673
# → Model evaluation #674
# → Model evaluation #675
# → Model evaluation #676
# → Model evaluation #677
# → Model evaluation #678
# → Model evaluation #679
# → Model evaluation #680
# → Model evaluation #681
# → Model evaluation #682
# → Model evaluation #683
# → Model evaluation #684
# → Model evaluation #685
# → Model evaluation #686
# → Model evaluation #687
# → Model evaluation #688
# → Model evaluation #689
# → Model evaluation #690
# → Model evaluation #691
# → Model evaluation #692
# → Model evaluation #693
# → Model evaluation #694
# → Model evaluation #695
# → Model evaluation #696
# → Model evaluation #697
# → Model evaluation #698
# → Model evaluation #699
# → Model evaluation #700
# → Model evaluation #701
# → Model evaluation #702
# → Model evaluation #703
# → Model evaluation #704
# → Model evaluation #705
# → Model evaluation #706
# → Model evaluation #707
# → Model evaluation #708
# → Model evaluation #709
# → Model evaluation #710
# → Model evaluation #711
# → Model evaluation #712
# → Model evaluation #713
# → Model evaluation #714
# → Model evaluation #715
# → Model evaluation #716
# → Model evaluation #717
# → Model evaluation #718
# → Model evaluation #719
# → Model evaluation #720
# → Model evaluation #721
# → Model evaluation #722
# → Model evaluation #723
# → Model evaluation #724
# → Model evaluation #725
# → Model evaluation #726
# → Model evaluation #727
# → Model evaluation #728
# → Model evaluation #729
# → Model evaluation #730
# → Model evaluation #731
# → Model evaluation #732
# → Model evaluation #733
# → Model evaluation #734
# → Model evaluation #735
# → Model evaluation #736
# → Model evaluation #737
# → Model evaluation #738
# → Model evaluation #739
# → Model evaluation #740
# → Model evaluation #741
# → Model evaluation #742
# → Model evaluation #743
# → Model evaluation #744
# → Model evaluation #745
# → Model evaluation #746
# → Model evaluation #747
# → Model evaluation #748
# → Model evaluation #749
# → Model evaluation #750
# → Model evaluation #751
# → Model evaluation #752
# → Model evaluation #753
# → Model evaluation #754
# → Model evaluation #755
# → Model evaluation #756
# → Model evaluation #757
# → Model evaluation #758
# → Model evaluation #759
# → Model evaluation #760
# → Model evaluation #761
# → Model evaluation #762
# → Model evaluation #763
# → Model evaluation #764
# → Model evaluation #765
# → Model evaluation #766
# → Model evaluation #767
# → Model evaluation #768
# → Model evaluation #769
# → Model evaluation #770
# → Model evaluation #771
# → Model evaluation #772
# → Model evaluation #773
# → Model evaluation #774
# → Model evaluation #775
# → Model evaluation #776
# → Model evaluation #777
# → Model evaluation #778
# → Model evaluation #779
# → Model evaluation #780
# → Model evaluation #781
# → Model evaluation #782
# → Model evaluation #783
# → Model evaluation #784
# → Model evaluation #785
# → Model evaluation #786
# → Model evaluation #787
# → Model evaluation #788
# → Model evaluation #789
# → Model evaluation #790
# → Model evaluation #791
# → Model evaluation #792
# → Model evaluation #793
# → Model evaluation #794
# → Model evaluation #795
# → Model evaluation #796
# → Model evaluation #797
# → Model evaluation #798
# → Model evaluation #799
# → Model evaluation #800
# → Model evaluation #801
# → Model evaluation #802
# → Model evaluation #803
# → Model evaluation #804
# → Model evaluation #805
# → Model evaluation #806
# → Model evaluation #807
# → Model evaluation #808
# → Model evaluation #809
# → Model evaluation #810
# → Model evaluation #811
# → Model evaluation #812
# → Model evaluation #813
# → Model evaluation #814
# → Model evaluation #815
# → Model evaluation #816
# → Model evaluation #817
# → Model evaluation #818
# → Model evaluation #819
# → Model evaluation #820
# → Model evaluation #821
# → Model evaluation #822
# → Model evaluation #823
# → Model evaluation #824
# → Model evaluation #825
# → Model evaluation #826
# → Model evaluation #827
# → Model evaluation #828
# → Model evaluation #829
# → Model evaluation #830
# → Model evaluation #831
# → Model evaluation #832
# → Model evaluation #833
# → Model evaluation #834
# → Model evaluation #835
# → Model evaluation #836
# → Model evaluation #837
# → Model evaluation #838
# → Model evaluation #839
# → Model evaluation #840
# → Model evaluation #841
# → Model evaluation #842
# → Model evaluation #843
# → Model evaluation #844
# → Model evaluation #845
# → Model evaluation #846
# → Model evaluation #847
# → Model evaluation #848
# → Model evaluation #849
# → Model evaluation #850
# → Model evaluation #851
# → Model evaluation #852
# → Model evaluation #853
# → Model evaluation #854
# → Model evaluation #855
# → Model evaluation #856
# → Model evaluation #857
# → Model evaluation #858
# → Model evaluation #859
# → Model evaluation #860
# → Model evaluation #861
# → Model evaluation #862
# → Model evaluation #863
# → Model evaluation #864
# → Model evaluation #865
# → Model evaluation #866
# → Model evaluation #867
# → Model evaluation #868
# → Model evaluation #869
# → Model evaluation #870
# → Model evaluation #871
# → Model evaluation #872
# → Model evaluation #873
# → Model evaluation #874
# → Model evaluation #875
# → Model evaluation #876
# → Model evaluation #877
# → Model evaluation #878
# → Model evaluation #879
# → Model evaluation #880
# → Model evaluation #881
# → Model evaluation #882
# → Model evaluation #883
# → Model evaluation #884
# → Model evaluation #885
# → Model evaluation #886
# → Model evaluation #887
# → Model evaluation #888
# → Model evaluation #889
# → Model evaluation #890
# → Model evaluation #891
# → Model evaluation #892
# → Model evaluation #893
# → Model evaluation #894
# → Model evaluation #895
# → Model evaluation #896
# → Model evaluation #897
# → Model evaluation #898
# → Model evaluation #899
# → Model evaluation #900
# → Model evaluation #901
# → Model evaluation #902
# → Model evaluation #903
# → Model evaluation #904
# → Model evaluation #905
# → Model evaluation #906
# → Model evaluation #907
# → Model evaluation #908
# → Model evaluation #909
# → Model evaluation #910
# → Model evaluation #911
# → Model evaluation #912
# → Model evaluation #913
# → Model evaluation #914
# → Model evaluation #915
# → Model evaluation #916
# → Model evaluation #917
# → Model evaluation #918
# → Model evaluation #919
# → Model evaluation #920
# → Model evaluation #921
# → Model evaluation #922
# → Model evaluation #923
# → Model evaluation #924
# → Model evaluation #925
# → Model evaluation #926
# → Model evaluation #927
# → Model evaluation #928
# → Model evaluation #929
# → Model evaluation #930
# → Model evaluation #931
# → Model evaluation #932
# → Model evaluation #933
# → Model evaluation #934
# → Model evaluation #935
# → Model evaluation #936
# → Model evaluation #937
# → Model evaluation #938
# → Model evaluation #939
# → Model evaluation #940
# → Model evaluation #941
# → Model evaluation #942
# → Model evaluation #943
# → Model evaluation #944
# → Model evaluation #945
# → Model evaluation #946
# → Model evaluation #947
# → Model evaluation #948
# → Model evaluation #949
# → Model evaluation #950
# → Model evaluation #951
# → Model evaluation #952
# → Model evaluation #953
# → Model evaluation #954
# → Model evaluation #955
# → Model evaluation #956
# → Model evaluation #957
# → Model evaluation #958
# → Model evaluation #959
# → Model evaluation #960
# → Model evaluation #961
# → Model evaluation #962
# → Model evaluation #963
# → Model evaluation #964
# → Model evaluation #965
# → Model evaluation #966
# → Model evaluation #967
# → Model evaluation #968
# → Model evaluation #969
# → Model evaluation #970
# → Model evaluation #971
# → Model evaluation #972
# → Model evaluation #973
# → Model evaluation #974
# → Model evaluation #975
# → Model evaluation #976
# → Model evaluation #977
# → Model evaluation #978
# → Model evaluation #979
# → Model evaluation #980
# → Model evaluation #981
# → Model evaluation #982
# → Model evaluation #983
# → Model evaluation #984
# → Model evaluation #985
# → Model evaluation #986
# → Model evaluation #987
# → Model evaluation #988
# → Model evaluation #989
# → Model evaluation #990
# → Model evaluation #991
# → Model evaluation #992
# → Model evaluation #993
# → Model evaluation #994
# → Model evaluation #995
# → Model evaluation #996
# → Model evaluation #997
# → Model evaluation #998
# → Model evaluation #999
# → Model evaluation #1000
# → Model evaluation #1001
# → Model evaluation #1002
# → Model evaluation #1003
# → Model evaluation #1004
# → Model evaluation #1005
# → Model evaluation #1006
# → Model evaluation #1007
# → Model evaluation #1008
# → Model evaluation #1009
# → Model evaluation #1010
# → Model evaluation #1011
# → Model evaluation #1012
# → Model evaluation #1013
# → Model evaluation #1014
# → Model evaluation #1015
# → Model evaluation #1016
# → Model evaluation #1017
# → Model evaluation #1018
# → Model evaluation #1019
# → Model evaluation #1020
# → Model evaluation #1021
# → Model evaluation #1022
# → Model evaluation #1023
# → Model evaluation #1024
# → Model evaluation #1025
# → Model evaluation #1026
# → Model evaluation #1027
# → Model evaluation #1028
# → Model evaluation #1029
# → Model evaluation #1030
# → Model evaluation #1031
# → Model evaluation #1032
# → Model evaluation #1033
# → Model evaluation #1034
# → Model evaluation #1035
# → Model evaluation #1036
# → Model evaluation #1037
# → Model evaluation #1038
# → Model evaluation #1039
# → Model evaluation #1040
# → Model evaluation #1041
# → Model evaluation #1042
# → Model evaluation #1043
# → Model evaluation #1044
# → Model evaluation #1045
# → Model evaluation #1046
# → Model evaluation #1047
# → Model evaluation #1048
# → Model evaluation #1049
# → Model evaluation #1050
# → Model evaluation #1051
# → Model evaluation #1052
# → Model evaluation #1053
# → Model evaluation #1054
# → Model evaluation #1055
# → Model evaluation #1056
# → Model evaluation #1057
# → Model evaluation #1058
# → Model evaluation #1059
# → Model evaluation #1060
# → Model evaluation #1061
# → Model evaluation #1062
# → Model evaluation #1063
# → Model evaluation #1064
# → Model evaluation #1065
# → Model evaluation #1066
# → Model evaluation #1067
# → Model evaluation #1068
# → Model evaluation #1069
# → Model evaluation #1070
# → Model evaluation #1071
# → Model evaluation #1072
# → Model evaluation #1073
# → Model evaluation #1074
# → Model evaluation #1075
# → Model evaluation #1076
# → Model evaluation #1077
# → Model evaluation #1078
# → Model evaluation #1079
# → Model evaluation #1080
# → Model evaluation #1081
# → Model evaluation #1082
# → Model evaluation #1083
# → Model evaluation #1084
# → Model evaluation #1085
# → Model evaluation #1086
# → Model evaluation #1087
# → Model evaluation #1088
# → Model evaluation #1089
# → Model evaluation #1090
# → Model evaluation #1091
# → Model evaluation #1092
# → Model evaluation #1093
# → Model evaluation #1094
# → Model evaluation #1095
# → Model evaluation #1096
# → Model evaluation #1097
# → Model evaluation #1098
# → Model evaluation #1099
# → Model evaluation #1100
# → Model evaluation #1101
# → Model evaluation #1102
# → Model evaluation #1103
# → Model evaluation #1104
# → Model evaluation #1105
# → Model evaluation #1106
# → Model evaluation #1107
# → Model evaluation #1108
# → Model evaluation #1109
# → Model evaluation #1110
# → Model evaluation #1111
# → Model evaluation #1112
# → Model evaluation #1113
# → Model evaluation #1114
# → Model evaluation #1115
# → Model evaluation #1116
# → Model evaluation #1117
# → Model evaluation #1118
# → Model evaluation #1119
# → Model evaluation #1120
# → Model evaluation #1121
# → Model evaluation #1122
# → Model evaluation #1123
# → Model evaluation #1124
# → Model evaluation #1125
# → Model evaluation #1126
# → Model evaluation #1127
# → Model evaluation #1128
# → Model evaluation #1129
# → Model evaluation #1130
# → Model evaluation #1131
# → Model evaluation #1132
# → Model evaluation #1133
# → Model evaluation #1134
# → Model evaluation #1135
# → Model evaluation #1136
# → Model evaluation #1137
# → Model evaluation #1138
# → Model evaluation #1139
# → Model evaluation #1140
# → Model evaluation #1141
# → Model evaluation #1142
# → Model evaluation #1143
# → Model evaluation #1144
# → Model evaluation #1145
# → Model evaluation #1146
# → Model evaluation #1147
# → Model evaluation #1148
# → Model evaluation #1149
# → Model evaluation #1150
# → Model evaluation #1151
# → Model evaluation #1152
# → Model evaluation #1153
# → Model evaluation #1154
# → Model evaluation #1155
# → Model evaluation #1156
# → Model evaluation #1157
# → Model evaluation #1158
# → Model evaluation #1159
# → Model evaluation #1160
# → Model evaluation #1161
# → Model evaluation #1162
# → Model evaluation #1163
# → Model evaluation #1164
# → Model evaluation #1165
# → Model evaluation #1166
# → Model evaluation #1167
# → Model evaluation #1168
# → Model evaluation #1169
# → Model evaluation #1170
# → Model evaluation #1171
# → Model evaluation #1172
# → Model evaluation #1173
# → Model evaluation #1174
# → Model evaluation #1175
# → Model evaluation #1176
# → Model evaluation #1177
# → Model evaluation #1178
# → Model evaluation #1179
# → Model evaluation #1180
# → Model evaluation #1181
# → Model evaluation #1182
# → Model evaluation #1183
# → Model evaluation #1184
# → Model evaluation #1185
# → Model evaluation #1186
# → Model evaluation #1187
# → Model evaluation #1188
# → Model evaluation #1189
# → Model evaluation #1190
# → Model evaluation #1191
# → Model evaluation #1192
# → Model evaluation #1193
# → Model evaluation #1194
# → Model evaluation #1195
# → Model evaluation #1196
# → Model evaluation #1197
# → Model evaluation #1198
# → Model evaluation #1199
# → Model evaluation #1200
# → Model evaluation #1201
# → Model evaluation #1202
# → Model evaluation #1203
# → Model evaluation #1204
# → Model evaluation #1205
# → Model evaluation #1206
# → Model evaluation #1207
# → Model evaluation #1208
# → Model evaluation #1209
# → Model evaluation #1210
# → Model evaluation #1211
# → Model evaluation #1212
# → Model evaluation #1213
# → Model evaluation #1214
# → Model evaluation #1215
# → Model evaluation #1216
# → Model evaluation #1217
# → Model evaluation #1218
# → Model evaluation #1219
# → Model evaluation #1220
# → Model evaluation #1221
# → Model evaluation #1222
# → Model evaluation #1223
# → Model evaluation #1224
# → Model evaluation #1225
# → Model evaluation #1226
# → Model evaluation #1227
# → Model evaluation #1228
# → Model evaluation #1229
# → Model evaluation #1230
# → Model evaluation #1231
# → Model evaluation #1232
# → Model evaluation #1233
# → Model evaluation #1234
# → Model evaluation #1235
# → Model evaluation #1236
# → Model evaluation #1237
# → Model evaluation #1238
# → Model evaluation #1239
# → Model evaluation #1240
# → Model evaluation #1241
# → Model evaluation #1242
# → Model evaluation #1243
# → Model evaluation #1244
# → Model evaluation #1245
# → Model evaluation #1246
# → Model evaluation #1247
# → Model evaluation #1248
# → Model evaluation #1249
# → Model evaluation #1250
# → Model evaluation #1251
# → Model evaluation #1252
# → Model evaluation #1253
# → Model evaluation #1254
# → Model evaluation #1255
# → Model evaluation #1256
# → Model evaluation #1257
# → Model evaluation #1258
# → Model evaluation #1259
# → Model evaluation #1260
# → Model evaluation #1261
# → Model evaluation #1262
# → Model evaluation #1263
# → Model evaluation #1264
# → Model evaluation #1265
# → Model evaluation #1266
# → Model evaluation #1267
# → Model evaluation #1268
# → Model evaluation #1269
# → Model evaluation #1270
# → Model evaluation #1271
# → Model evaluation #1272
# → Model evaluation #1273
# → Model evaluation #1274
# → Model evaluation #1275
# → Model evaluation #1276
# → Model evaluation #1277
# → Model evaluation #1278
# → Model evaluation #1279
# → Model evaluation #1280
# → Model evaluation #1281
# → Model evaluation #1282
# → Model evaluation #1283
# → Model evaluation #1284
# → Model evaluation #1285
# → Model evaluation #1286
# → Model evaluation #1287
# → Model evaluation #1288
# → Model evaluation #1289
# → Model evaluation #1290
# → Model evaluation #1291
# → Model evaluation #1292
# → Model evaluation #1293
# → Model evaluation #1294
# → Model evaluation #1295
# → Model evaluation #1296
# → Model evaluation #1297
# → Model evaluation #1298
# → Model evaluation #1299
# → Model evaluation #1300
# → Model evaluation #1301
# → Model evaluation #1302
# → Model evaluation #1303
# → Model evaluation #1304
# → Model evaluation #1305
# → Model evaluation #1306
# → Model evaluation #1307
# → Model evaluation #1308
# → Model evaluation #1309
# → Model evaluation #1310
# → Model evaluation #1311
# → Model evaluation #1312
# → Model evaluation #1313
# → Model evaluation #1314
# → Model evaluation #1315
# → Model evaluation #1316
# → Model evaluation #1317
# → Model evaluation #1318
# → Model evaluation #1319
# → Model evaluation #1320
# → Model evaluation #1321
# → Model evaluation #1322
# → Model evaluation #1323
# → Model evaluation #1324
# → Model evaluation #1325
# → Model evaluation #1326
# → Model evaluation #1327
# → Model evaluation #1328
# → Model evaluation #1329
# → Model evaluation #1330
# → Model evaluation #1331
# → Model evaluation #1332
# → Model evaluation #1333
# → Model evaluation #1334
# → Model evaluation #1335
# → Model evaluation #1336
# → Model evaluation #1337
# → Model evaluation #1338
# → Model evaluation #1339
# → Model evaluation #1340
# → Model evaluation #1341
# → Model evaluation #1342
# → Model evaluation #1343
# → Model evaluation #1344
# → Model evaluation #1345
# → Model evaluation #1346
# → Model evaluation #1347
# → Model evaluation #1348
# → Model evaluation #1349
# → Model evaluation #1350
# → Model evaluation #1351
# → Model evaluation #1352
# → Model evaluation #1353
# → Model evaluation #1354
# → Model evaluation #1355
# → Model evaluation #1356
# → Model evaluation #1357
# → Model evaluation #1358
# → Model evaluation #1359
# → Model evaluation #1360
# → Model evaluation #1361
# → Model evaluation #1362
# → Model evaluation #1363
# → Model evaluation #1364
# → Model evaluation #1365
# → Model evaluation #1366
# → Model evaluation #1367
# → Model evaluation #1368
# → Model evaluation #1369
# → Model evaluation #1370
# → Model evaluation #1371
# → Model evaluation #1372
# → Model evaluation #1373
# → Model evaluation #1374
# → Model evaluation #1375
# → Model evaluation #1376
# → Model evaluation #1377
# → Model evaluation #1378
# → Model evaluation #1379
# → Model evaluation #1380
# → Model evaluation #1381
# → Model evaluation #1382
# → Model evaluation #1383
# → Model evaluation #1384
# → Model evaluation #1385
# → Model evaluation #1386
# → Model evaluation #1387
# → Model evaluation #1388
# → Model evaluation #1389
# → Model evaluation #1390
# → Model evaluation #1391
# → Model evaluation #1392
# → Model evaluation #1393
# → Model evaluation #1394
# → Model evaluation #1395
# → Model evaluation #1396
# → Model evaluation #1397
# → Model evaluation #1398
# → Model evaluation #1399
# → Model evaluation #1400
# → Model evaluation #1401
# → Model evaluation #1402
# → Model evaluation #1403
# → Model evaluation #1404
# → Model evaluation #1405
# → Model evaluation #1406
# → Model evaluation #1407
# → Model evaluation #1408
# → Model evaluation #1409
# → Model evaluation #1410
# → Model evaluation #1411
# → Model evaluation #1412
# → Model evaluation #1413
# → Model evaluation #1414
# → Model evaluation #1415
# → Model evaluation #1416
# → Model evaluation #1417
# → Model evaluation #1418
# → Model evaluation #1419
# → Model evaluation #1420
# → Model evaluation #1421
# → Model evaluation #1422
# → Model evaluation #1423
# → Model evaluation #1424
# → Model evaluation #1425
# → Model evaluation #1426
# → Model evaluation #1427
# → Model evaluation #1428
# → Model evaluation #1429
# → Model evaluation #1430
# → Model evaluation #1431
# → Model evaluation #1432
# → Model evaluation #1433
# → Model evaluation #1434
# → Model evaluation #1435
# → Model evaluation #1436
# → Model evaluation #1437
# → Model evaluation #1438
# → Model evaluation #1439
# → Model evaluation #1440
# → Model evaluation #1441
# → Model evaluation #1442
# → Model evaluation #1443
# → Model evaluation #1444
# → Model evaluation #1445
# → Model evaluation #1446
# → Model evaluation #1447
# → Model evaluation #1448
# → Model evaluation #1449
# → Model evaluation #1450
# → Model evaluation #1451
# → Model evaluation #1452
# → Model evaluation #1453
# → Model evaluation #1454
# → Model evaluation #1455
# → Model evaluation #1456
# → Model evaluation #1457
# → Model evaluation #1458
# → Model evaluation #1459
# → Model evaluation #1460
# → Model evaluation #1461
# → Model evaluation #1462
# → Model evaluation #1463
# → Model evaluation #1464
# → Model evaluation #1465
# → Model evaluation #1466
# → Model evaluation #1467
# → Model evaluation #1468
# → Model evaluation #1469
# → Model evaluation #1470
# → Model evaluation #1471
# → Model evaluation #1472
# → Model evaluation #1473
# → Model evaluation #1474
# → Model evaluation #1475
# → Model evaluation #1476
# → Model evaluation #1477
# → Model evaluation #1478
# → Model evaluation #1479
# → Model evaluation #1480
# → Model evaluation #1481
# → Model evaluation #1482
# → Model evaluation #1483
# → Model evaluation #1484
# → Model evaluation #1485
# → Model evaluation #1486
# → Model evaluation #1487
# → Model evaluation #1488
# → Model evaluation #1489
# → Model evaluation #1490
# → Model evaluation #1491
# → Model evaluation #1492
# → Model evaluation #1493
# → Model evaluation #1494
# → Model evaluation #1495
# → Model evaluation #1496
# → Model evaluation #1497
# → Model evaluation #1498
# → Model evaluation #1499
# → Model evaluation #1500
# → Model evaluation #1501
# → Model evaluation #1502
# → Model evaluation #1503
# → Model evaluation #1504
# → Model evaluation #1505
# → Model evaluation #1506
# → Model evaluation #1507
# → Model evaluation #1508
# → Model evaluation #1509
# → Model evaluation #1510
# → Model evaluation #1511
# → Model evaluation #1512
# → Model evaluation #1513
# → Model evaluation #1514
# → Model evaluation #1515
# → Model evaluation #1516
# → Model evaluation #1517
# → Model evaluation #1518
# → Model evaluation #1519
# → Model evaluation #1520
# → Model evaluation #1521
# → Model evaluation #1522
# → Model evaluation #1523
# → Model evaluation #1524
# → Model evaluation #1525
# → Model evaluation #1526
# → Model evaluation #1527
# → Model evaluation #1528
# → Model evaluation #1529
# → Model evaluation #1530
# → Model evaluation #1531
# → Model evaluation #1532
# → Model evaluation #1533
# → Model evaluation #1534
# → Model evaluation #1535
# → Model evaluation #1536
# → Model evaluation #1537
# → Model evaluation #1538
# → Model evaluation #1539
# → Model evaluation #1540
# → Model evaluation #1541
# → Model evaluation #1542
# → Model evaluation #1543
# → Model evaluation #1544
# → Model evaluation #1545
# → Model evaluation #1546
# → Model evaluation #1547
# → Model evaluation #1548
# → Model evaluation #1549
# → Model evaluation #1550
# → Model evaluation #1551
# → Model evaluation #1552
# → Model evaluation #1553
# → Model evaluation #1554
# → Model evaluation #1555
# → Model evaluation #1556
# → Model evaluation #1557
# → Model evaluation #1558
# → Model evaluation #1559
# → Model evaluation #1560
# → Model evaluation #1561
# → Model evaluation #1562
# → Model evaluation #1563
# → Model evaluation #1564
# → Model evaluation #1565
# → Model evaluation #1566
# → Model evaluation #1567
# → Model evaluation #1568
# → Model evaluation #1569
# → Model evaluation #1570
# → Model evaluation #1571
# → Model evaluation #1572
# → Model evaluation #1573
# → Model evaluation #1574
# → Model evaluation #1575
# → Model evaluation #1576
# → Model evaluation #1577
# → Model evaluation #1578
# → Model evaluation #1579
# ⚠️ Simulated streamflow contains NaN or inf → penalizing solution
# → Model evaluation #1580
# → Model evaluation #1581
# → Model evaluation #1582
# → Model evaluation #1583
# → Model evaluation #1584
# → Model evaluation #1585
# → Model evaluation #1586
# → Model evaluation #1587
# → Model evaluation #1588
# → Model evaluation #1589
# → Model evaluation #1590
# → Model evaluation #1591
# → Model evaluation #1592
# → Model evaluation #1593
# → Model evaluation #1594
# → Model evaluation #1595
# → Model evaluation #1596
# → Model evaluation #1597
# → Model evaluation #1598
# → Model evaluation #1599
# → Model evaluation #1600
# → Model evaluation #1601
# → Model evaluation #1602
# → Model evaluation #1603
# → Model evaluation #1604
# → Model evaluation #1605
# → Model evaluation #1606
# → Model evaluation #1607
# → Model evaluation #1608
# → Model evaluation #1609
# → Model evaluation #1610
# → Model evaluation #1611
# → Model evaluation #1612
# → Model evaluation #1613
# → Model evaluation #1614
# → Model evaluation #1615
# → Model evaluation #1616
# → Model evaluation #1617
# → Model evaluation #1618
# → Model evaluation #1619
# → Model evaluation #1620
# → Model evaluation #1621
# → Model evaluation #1622
# → Model evaluation #1623
# → Model evaluation #1624
# → Model evaluation #1625
# → Model evaluation #1626
# → Model evaluation #1627
# → Model evaluation #1628
# → Model evaluation #1629
# → Model evaluation #1630
# → Model evaluation #1631
# → Model evaluation #1632
# → Model evaluation #1633
# → Model evaluation #1634
# → Model evaluation #1635
# → Model evaluation #1636
# → Model evaluation #1637
# → Model evaluation #1638
# → Model evaluation #1639
# → Model evaluation #1640
# → Model evaluation #1641
# → Model evaluation #1642
# → Model evaluation #1643
# → Model evaluation #1644
# → Model evaluation #1645
# → Model evaluation #1646
# → Model evaluation #1647
# → Model evaluation #1648
# → Model evaluation #1649
# → Model evaluation #1650
# → Model evaluation #1651
# → Model evaluation #1652
# → Model evaluation #1653
# → Model evaluation #1654
# → Model evaluation #1655
# → Model evaluation #1656
# → Model evaluation #1657
# → Model evaluation #1658
# → Model evaluation #1659
# → Model evaluation #1660
# → Model evaluation #1661
# → Model evaluation #1662
# → Model evaluation #1663
# → Model evaluation #1664
# → Model evaluation #1665
# → Model evaluation #1666
# → Model evaluation #1667
# → Model evaluation #1668
# → Model evaluation #1669
# → Model evaluation #1670
# → Model evaluation #1671
# → Model evaluation #1672
# → Model evaluation #1673
# → Model evaluation #1674
# → Model evaluation #1675
# → Model evaluation #1676
# → Model evaluation #1677
# → Model evaluation #1678
# → Model evaluation #1679
# → Model evaluation #1680
# → Model evaluation #1681
# → Model evaluation #1682
# → Model evaluation #1683
# → Model evaluation #1684
# → Model evaluation #1685
# → Model evaluation #1686
# → Model evaluation #1687
# → Model evaluation #1688
# → Model evaluation #1689
# → Model evaluation #1690
# → Model evaluation #1691
# → Model evaluation #1692
# → Model evaluation #1693
# → Model evaluation #1694
# → Model evaluation #1695
# → Model evaluation #1696
# → Model evaluation #1697
# → Model evaluation #1698
# → Model evaluation #1699
# → Model evaluation #1700
# → Model evaluation #1701
# → Model evaluation #1702
# → Model evaluation #1703
# → Model evaluation #1704
# → Model evaluation #1705
# → Model evaluation #1706
# → Model evaluation #1707
# → Model evaluation #1708
# → Model evaluation #1709
# → Model evaluation #1710
# → Model evaluation #1711
# → Model evaluation #1712
# → Model evaluation #1713
# → Model evaluation #1714
# → Model evaluation #1715
# → Model evaluation #1716
# → Model evaluation #1717
# → Model evaluation #1718
# → Model evaluation #1719
# → Model evaluation #1720
# → Model evaluation #1721
# → Model evaluation #1722
# → Model evaluation #1723
# → Model evaluation #1724
# → Model evaluation #1725
# → Model evaluation #1726
# → Model evaluation #1727
# → Model evaluation #1728
# → Model evaluation #1729
# → Model evaluation #1730
# → Model evaluation #1731
# → Model evaluation #1732
# → Model evaluation #1733
# → Model evaluation #1734
# → Model evaluation #1735
# → Model evaluation #1736
# → Model evaluation #1737
# → Model evaluation #1738
# → Model evaluation #1739
# → Model evaluation #1740
# → Model evaluation #1741
# → Model evaluation #1742
# → Model evaluation #1743
# → Model evaluation #1744
# → Model evaluation #1745
# → Model evaluation #1746
# → Model evaluation #1747
# → Model evaluation #1748
# → Model evaluation #1749
# → Model evaluation #1750
# → Model evaluation #1751
# → Model evaluation #1752
# → Model evaluation #1753
# → Model evaluation #1754
# → Model evaluation #1755
# → Model evaluation #1756
# → Model evaluation #1757
# → Model evaluation #1758
# → Model evaluation #1759
# → Model evaluation #1760
# → Model evaluation #1761
# → Model evaluation #1762
# → Model evaluation #1763
# → Model evaluation #1764
# → Model evaluation #1765
# → Model evaluation #1766
# → Model evaluation #1767
# → Model evaluation #1768
# → Model evaluation #1769
# → Model evaluation #1770
# → Model evaluation #1771
# → Model evaluation #1772
# → Model evaluation #1773
# → Model evaluation #1774
# → Model evaluation #1775
# → Model evaluation #1776
# → Model evaluation #1777
# ⚠️ Simulated streamflow contains NaN or inf → penalizing solution
# → Model evaluation #1778
# → Model evaluation #1779
# → Model evaluation #1780
# → Model evaluation #1781
# → Model evaluation #1782
# → Model evaluation #1783
# → Model evaluation #1784
# → Model evaluation #1785
# → Model evaluation #1786
# → Model evaluation #1787
# → Model evaluation #1788
# → Model evaluation #1789
# → Model evaluation #1790
# → Model evaluation #1791
# → Model evaluation #1792
# → Model evaluation #1793
# → Model evaluation #1794
# → Model evaluation #1795
# → Model evaluation #1796
# → Model evaluation #1797
# → Model evaluation #1798
# → Model evaluation #1799
# → Model evaluation #1800
# → Model evaluation #1801
# → Model evaluation #1802
# → Model evaluation #1803
# → Model evaluation #1804
# → Model evaluation #1805
# → Model evaluation #1806
# → Model evaluation #1807
# → Model evaluation #1808
# → Model evaluation #1809
# → Model evaluation #1810
# → Model evaluation #1811
# → Model evaluation #1812
# → Model evaluation #1813
# → Model evaluation #1814
# → Model evaluation #1815
# → Model evaluation #1816
# → Model evaluation #1817
# → Model evaluation #1818
# → Model evaluation #1819
# → Model evaluation #1820
# → Model evaluation #1821
# → Model evaluation #1822
# → Model evaluation #1823
# → Model evaluation #1824
# → Model evaluation #1825
# → Model evaluation #1826
# → Model evaluation #1827
# → Model evaluation #1828
# → Model evaluation #1829
# → Model evaluation #1830
# → Model evaluation #1831
# → Model evaluation #1832
# → Model evaluation #1833
# → Model evaluation #1834
# → Model evaluation #1835
# → Model evaluation #1836
# → Model evaluation #1837
# → Model evaluation #1838
# → Model evaluation #1839
# → Model evaluation #1840
# → Model evaluation #1841
# → Model evaluation #1842
# → Model evaluation #1843
# → Model evaluation #1844
# → Model evaluation #1845
# → Model evaluation #1846
# → Model evaluation #1847
# → Model evaluation #1848
# → Model evaluation #1849
# → Model evaluation #1850
# → Model evaluation #1851
# → Model evaluation #1852
# → Model evaluation #1853
# → Model evaluation #1854
# → Model evaluation #1855
# → Model evaluation #1856
# → Model evaluation #1857
# → Model evaluation #1858
# → Model evaluation #1859
# → Model evaluation #1860
# → Model evaluation #1861
# → Model evaluation #1862
# → Model evaluation #1863
# → Model evaluation #1864
# → Model evaluation #1865
# → Model evaluation #1866
# → Model evaluation #1867
# → Model evaluation #1868
# → Model evaluation #1869
# → Model evaluation #1870
# → Model evaluation #1871
# → Model evaluation #1872
# → Model evaluation #1873
# → Model evaluation #1874
# → Model evaluation #1875
# → Model evaluation #1876
# → Model evaluation #1877
# → Model evaluation #1878
# → Model evaluation #1879
# → Model evaluation #1880
# → Model evaluation #1881
# → Model evaluation #1882
# → Model evaluation #1883
# → Model evaluation #1884
# → Model evaluation #1885
# → Model evaluation #1886
# → Model evaluation #1887
# → Model evaluation #1888
# → Model evaluation #1889
# → Model evaluation #1890
# → Model evaluation #1891
# → Model evaluation #1892
# → Model evaluation #1893
# → Model evaluation #1894
# → Model evaluation #1895
# → Model evaluation #1896
# → Model evaluation #1897
# → Model evaluation #1898
# → Model evaluation #1899
# → Model evaluation #1900
# → Model evaluation #1901
# → Model evaluation #1902
# → Model evaluation #1903
# → Model evaluation #1904
# → Model evaluation #1905
# → Model evaluation #1906
# → Model evaluation #1907
# → Model evaluation #1908
# → Model evaluation #1909
# → Model evaluation #1910
# → Model evaluation #1911
# → Model evaluation #1912
# → Model evaluation #1913
# → Model evaluation #1914
# → Model evaluation #1915
# → Model evaluation #1916
# → Model evaluation #1917
# → Model evaluation #1918
# → Model evaluation #1919
# → Model evaluation #1920
# → Model evaluation #1921
# → Model evaluation #1922
# → Model evaluation #1923
# → Model evaluation #1924
# → Model evaluation #1925
# → Model evaluation #1926
# → Model evaluation #1927
# → Model evaluation #1928
# → Model evaluation #1929
# → Model evaluation #1930
# → Model evaluation #1931
# → Model evaluation #1932
# → Model evaluation #1933
# → Model evaluation #1934
# → Model evaluation #1935
# → Model evaluation #1936
# → Model evaluation #1937
# → Model evaluation #1938
# → Model evaluation #1939
# → Model evaluation #1940
# → Model evaluation #1941
# → Model evaluation #1942
# → Model evaluation #1943
# → Model evaluation #1944
# → Model evaluation #1945
# → Model evaluation #1946
# → Model evaluation #1947
# → Model evaluation #1948
# → Model evaluation #1949
# → Model evaluation #1950
# → Model evaluation #1951
# ...
# → Model evaluation #3585
# → Model evaluation #3586
# → Model evaluation #3587
# → Model evaluation #3588
# → Model evaluation #3589
# → Model evaluation #3590
# → Model evaluation #3591
# → Model evaluation #3592
# → Model evaluation #3593
# → Model evaluation #3594
# → Model evaluation #3595
# → Model evaluation #3596
# → Model evaluation #3597
# → Model evaluation #3598
# → Model evaluation #3599
# → Model evaluation #3600
# → Model evaluation #3601
# → Model evaluation #3602
# → Model evaluation #3603
# → Model evaluation #3604
# → Model evaluation #3605
# → Model evaluation #3606
# → Model evaluation #3607
# → Model evaluation #3608
# → Model evaluation #3609
# → Model evaluation #3610
# → Model evaluation #3611
# → Model evaluation #3612
# → Model evaluation #3613
# → Model evaluation #3614
# → Model evaluation #3615
# → Model evaluation #3616
# → Model evaluation #3617
# → Model evaluation #3618
# → Model evaluation #3619
# → Model evaluation #3620
# → Model evaluation #3621
# → Model evaluation #3622
# → Model evaluation #3623
# → Model evaluation #3624
# → Model evaluation #3625
# → Model evaluation #3626
# → Model evaluation #3627
# → Model evaluation #3628
# → Model evaluation #3629
# → Model evaluation #3630
# → Model evaluation #3631
# → Model evaluation #3632
# → Model evaluation #3633
# → Model evaluation #3634
# → Model evaluation #3635
# → Model evaluation #3636
# → Model evaluation #3637
# → Model evaluation #3638
# → Model evaluation #3639
# → Model evaluation #3640
# → Model evaluation #3641
# → Model evaluation #3642
# → Model evaluation #3643
# → Model evaluation #3644
# → Model evaluation #3645
# → Model evaluation #3646
# → Model evaluation #3647
# → Model evaluation #3648
# → Model evaluation #3649
# → Model evaluation #3650
# → Model evaluation #3651
# → Model evaluation #3652
# → Model evaluation #3653
# → Model evaluation #3654
# → Model evaluation #3655
# → Model evaluation #3656
# → Model evaluation #3657
# → Model evaluation #3658
# → Model evaluation #3659
# → Model evaluation #3660
# → Model evaluation #3661
# → Model evaluation #3662
# → Model evaluation #3663
# → Model evaluation #3664
# → Model evaluation #3665
# → Model evaluation #3666
# → Model evaluation #3667
# → Model evaluation #3668
# → Model evaluation #3669
# → Model evaluation #3670
# → Model evaluation #3671
# → Model evaluation #3672
# → Model evaluation #3673
# → Model evaluation #3674
# → Model evaluation #3675
# → Model evaluation #3676
# → Model evaluation #3677
# → Model evaluation #3678
# → Model evaluation #3679
# → Model evaluation #3680
# → Model evaluation #3681
# → Model evaluation #3682
# → Model evaluation #3683
# → Model evaluation #3684
# → Model evaluation #3685
# → Model evaluation #3686
# → Model evaluation #3687
# → Model evaluation #3688
# → Model evaluation #3689
# → Model evaluation #3690
# → Model evaluation #3691
# → Model evaluation #3692
# → Model evaluation #3693
# → Model evaluation #3694
# → Model evaluation #3695
# → Model evaluation #3696
# → Model evaluation #3697
# → Model evaluation #3698
# → Model evaluation #3699
# → Model evaluation #3700
# → Model evaluation #3701
# → Model evaluation #3702
# → Model evaluation #3703
# → Model evaluation #3704
# → Model evaluation #3705
# → Model evaluation #3706
# → Model evaluation #3707
# → Model evaluation #3708
# → Model evaluation #3709
# → Model evaluation #3710
# → Model evaluation #3711
# → Model evaluation #3712
# → Model evaluation #3713
# → Model evaluation #3714
# → Model evaluation #3715
# → Model evaluation #3716
# → Model evaluation #3717
# → Model evaluation #3718
# → Model evaluation #3719
# → Model evaluation #3720
# → Model evaluation #3721
# → Model evaluation #3722
# → Model evaluation #3723
# → Model evaluation #3724
# → Model evaluation #3725
# → Model evaluation #3726
# → Model evaluation #3727
# → Model evaluation #3728
# → Model evaluation #3729
# → Model evaluation #3730
# → Model evaluation #3731
# → Model evaluation #3732
# → Model evaluation #3733
# → Model evaluation #3734
# → Model evaluation #3735
# → Model evaluation #3736
# → Model evaluation #3737
# → Model evaluation #3738
# → Model evaluation #3739
# → Model evaluation #3740
# → Model evaluation #3741
# → Model evaluation #3742
# → Model evaluation #3743
# → Model evaluation #3744
# → Model evaluation #3745
# → Model evaluation #3746
# → Model evaluation #3747
# → Model evaluation #3748
# → Model evaluation #3749
# → Model evaluation #3750
# → Model evaluation #3751
# → Model evaluation #3752
# → Model evaluation #3753
# → Model evaluation #3754
# → Model evaluation #3755
# → Model evaluation #3756
# → Model evaluation #3757
# → Model evaluation #3758
# → Model evaluation #3759
# → Model evaluation #3760
# → Model evaluation #3761
# → Model evaluation #3762
# → Model evaluation #3763
# → Model evaluation #3764
# → Model evaluation #3765
# → Model evaluation #3766
# → Model evaluation #3767
# → Model evaluation #3768
# → Model evaluation #3769
# → Model evaluation #3770
# → Model evaluation #3771
# → Model evaluation #3772
# → Model evaluation #3773
# → Model evaluation #3774
# → Model evaluation #3775
# → Model evaluation #3776
# → Model evaluation #3777
# → Model evaluation #3778
# → Model evaluation #3779
# → Model evaluation #3780
# → Model evaluation #3781
# → Model evaluation #3782
# → Model evaluation #3783
# → Model evaluation #3784
# → Model evaluation #3785
# → Model evaluation #3786
# → Model evaluation #3787
# → Model evaluation #3788
# → Model evaluation #3789
# → Model evaluation #3790
# → Model evaluation #3791
# → Model evaluation #3792
# → Model evaluation #3793
# → Model evaluation #3794
# → Model evaluation #3795
# → Model evaluation #3796
# → Model evaluation #3797
# → Model evaluation #3798
# → Model evaluation #3799
# → Model evaluation #3800
# → Model evaluation #3801
# → Model evaluation #3802
# → Model evaluation #3803
# → Model evaluation #3804
# → Model evaluation #3805
# → Model evaluation #3806
# → Model evaluation #3807
# → Model evaluation #3808
# → Model evaluation #3809
# → Model evaluation #3810
# → Model evaluation #3811
# → Model evaluation #3812
# → Model evaluation #3813
# → Model evaluation #3814
# → Model evaluation #3815
# → Model evaluation #3816
# → Model evaluation #3817
# → Model evaluation #3818
# → Model evaluation #3819
# → Model evaluation #3820
# → Model evaluation #3821
# → Model evaluation #3822
# → Model evaluation #3823
# → Model evaluation #3824
# → Model evaluation #3825
# → Model evaluation #3826
# → Model evaluation #3827
# → Model evaluation #3828
# → Model evaluation #3829
# → Model evaluation #3830
# → Model evaluation #3831
# → Model evaluation #3832
# → Model evaluation #3833
# → Model evaluation #3834
# → Model evaluation #3835
# → Model evaluation #3836
# → Model evaluation #3837
# → Model evaluation #3838
# → Model evaluation #3839
# → Model evaluation #3840
# → Model evaluation #3841
# → Model evaluation #3842
# → Model evaluation #3843
# → Model evaluation #3844
# → Model evaluation #3845
# → Model evaluation #3846
# → Model evaluation #3847
# → Model evaluation #3848
# → Model evaluation #3849
# → Model evaluation #3850
# → Model evaluation #3851
# → Model evaluation #3852
# → Model evaluation #3853
# → Model evaluation #3854
# → Model evaluation #3855
# → Model evaluation #3856
# → Model evaluation #3857
# → Model evaluation #3858
# → Model evaluation #3859
# → Model evaluation #3860
# → Model evaluation #3861
# → Model evaluation #3862
# → Model evaluation #3863
# → Model evaluation #3864
# → Model evaluation #3865
# → Model evaluation #3866
# → Model evaluation #3867
# → Model evaluation #3868
# → Model evaluation #3869
# → Model evaluation #3870
# → Model evaluation #3871
# → Model evaluation #3872
# → Model evaluation #3873
# → Model evaluation #3874
# → Model evaluation #3875
# → Model evaluation #3876
# → Model evaluation #3877
# → Model evaluation #3878
# → Model evaluation #3879
# → Model evaluation #3880
# → Model evaluation #3881
# → Model evaluation #3882
# → Model evaluation #3883
# → Model evaluation #3884
# → Model evaluation #3885
# → Model evaluation #3886
# → Model evaluation #3887
# → Model evaluation #3888
# → Model evaluation #3889
# → Model evaluation #3890
# → Model evaluation #3891
# → Model evaluation #3892
# → Model evaluation #3893
# → Model evaluation #3894
# → Model evaluation #3895
# → Model evaluation #3896
# → Model evaluation #3897
# → Model evaluation #3898
# → Model evaluation #3899
# → Model evaluation #3900
# → Model evaluation #3901
# → Model evaluation #3902
# → Model evaluation #3903
# → Model evaluation #3904
# → Model evaluation #3905
# → Model evaluation #3906
# → Model evaluation #3907
# → Model evaluation #3908
# → Model evaluation #3909
# → Model evaluation #3910
# → Model evaluation #3911
# → Model evaluation #3912
# → Model evaluation #3913
# → Model evaluation #3914
# → Model evaluation #3915
# → Model evaluation #3916
# → Model evaluation #3917
# → Model evaluation #3918
# → Model evaluation #3919
# → Model evaluation #3920
# → Model evaluation #3921
# → Model evaluation #3922
# → Model evaluation #3923
# → Model evaluation #3924
# → Model evaluation #3925
# → Model evaluation #3926
# → Model evaluation #3927
# → Model evaluation #3928
# → Model evaluation #3929
# → Model evaluation #3930
# → Model evaluation #3931
# → Model evaluation #3932
# → Model evaluation #3933
# → Model evaluation #3934
# → Model evaluation #3935
# → Model evaluation #3936
# → Model evaluation #3937
# → Model evaluation #3938
# → Model evaluation #3939
# → Model evaluation #3940
# → Model evaluation #3941
# → Model evaluation #3942
# → Model evaluation #3943
# → Model evaluation #3944
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 16
#       7 landscapes = landscape_per # Example: 40% plateau, 50% hillslope, 10% wetland
#       9 param_bounds = {
#      10     'Plateau': [(0, 100), (0.1, 2), (0, 500), (0.1, 5), (0, 20), (0, 1)],
#      11     'Hillslope': [(0, 100), (0.1, 2), (0, 500), (0.1, 5), (0, 1), (0, 1)],
#      12     'Wetland': [(0, 100), (0.1, 2), (0, 500), (0.1, 5), (0, 20), (0, 1)],
#      13     'Catchment': [(0, 1), (0, 10)]
#      14 }
# ---> 16 optimized_params = calibrate_flextopo(forcing_data, landscapes, param_bounds)
#      18 for k, v in optimized_params.items():
#      19     print(f"{k}: {v}")
#
# Cell In[107], line 118, in calibrate_flextopo(forcing_data, landscapes, param_bounds, nse_weight)
#     109     return 1 - (nse_weight * nse + (1 - nse_weight) * log_nse)
#     111 bounds = (
#     112     param_bounds['Plateau'] +
#     113     param_bounds['Hillslope'] +
#     114     param_bounds['Wetland'] +
#     115     param_bounds['Catchment']
#     116 )
# --> 118 result = differential_evolution(objective, bounds, strategy='best1bin',
#     119                                 maxiter=10, popsize=10, tol=0.1,
#     120                                 mutation=(0.5, 1), recombination=0.7) #,  workers=-1)
#     122 opt = result.x
#     123 return {
#     124     'ParPlateau': opt[0:6],
#     125     'ParHillslope': opt[6:12],
#     126     'ParWetland': opt[12:18],
#     127     'ParCatchment': opt[18:]
#     128 }
#
# File c:\Users\Unieuro\miniconda3\envs\mude-base\Lib\site-packages\scipy\optimize\_differentialevolution.py:502, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     485 # using a context manager means that any created Pool objects are
#     486 # cleared up.
#     487 with DifferentialEvolutionSolver(func, bounds, args=args,
#     488                                  strategy=strategy,
#     489                                  maxiter=maxiter,
#    (...)
#     500                                  integrality=integrality,
#     501                                  vectorized=vectorized) as solver:
# --> 502     ret = solver.solve()
#     504 return ret
#
# File c:\Users\Unieuro\miniconda3\envs\mude-base\Lib\site-packages\scipy\optimize\_differentialevolution.py:1226, in DifferentialEvolutionSolver.solve(self)
#    1224 if self.disp:
#    1225     print(f"Polishing solution with '{polish_method}'")
# -> 1226 result = minimize(self.func,
#    1227                   np.copy(DE_result.x),
#    1228                   method=polish_method,
#    1229                   bounds=self.limits.T,
#    1230                   constraints=self.constraints)
#    1232 self._nfev += result.nfev
#    1233 DE_result.nfev = self._nfev
#
# File c:\Users\Unieuro\miniconda3\envs\mude-base\Lib\site-packages\scipy\optimize\_minimize.py:713, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#     712 elif meth == 'l-bfgs-b':
# --> 713     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     714                            callback=callback, **options)
#     715 elif meth == 'tnc':
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#
# File c:\Users\Unieuro\miniconda3\envs\mude-base\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:407, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     401 task_str = task.tobytes()
#     402 if task_str.startswith(b'FG'):
#     403     # The minimization routine wants f and g at the current x.
#     404     # Note that interruptions due to maxfun are postponed
#     405     # until the completion of the current minimization iteration.
#     406     # Overwrite f and g:
# --> 407     f, g = func_and_grad(x)
#     408 elif task_str.startswith(b'NEW_X'):
#     409     # new iteration
#     410     n_iterations += 1
#
# File c:\Users\Unieuro\miniconda3\envs\mude-base\Lib\site-packages\scipy\optimize\_differentiable_functions.py:296, in ScalarFunction.fun_and_grad(self, x)
#     294 if not np.array_equal(x, self.x):
#     295     self._update_x_impl(x)
# --> 296 self._update_fun()
#     297 self._update_grad()
#     298 return self.f, self.g
#
# File c:\Users\Unieuro\miniconda3\envs\mude-base\Lib\site-packages\scipy\optimize\_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File c:\Users\Unieuro\miniconda3\envs\mude-base\Lib\site-packages\scipy\optimize\_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File c:\Users\Unieuro\miniconda3\envs\mude-base\Lib\site-packages\scipy\optimize\_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File c:\Users\Unieuro\miniconda3\envs\mude-base\Lib\site-packages\scipy\_lib\_util.py:441, in _FunctionWrapper.__call__(self, x)
#     440 def __call__(self, x):
# --> 441     return self.f(x, *self.args)
#
# Cell In[107], line 81, in calibrate_flextopo.<locals>.objective(params)
#      79 ParWetland = params[2*n:3*n]
#      80 ParCatchment = params[3*n:]
# ---> 81 simulated = FLEXtopo(ParPlateau, ParHillslope, ParWetland, ParCatchment, forcing_data, landscapes)
#      83 if np.any(np.isnan(simulated)) or np.any(np.isinf(simulated)):
#      84     print("⚠️ Simulated streamflow contains NaN or inf → penalizing solution")
#
# Cell In[107], line 45, in FLEXtopo(ParPlateau, ParHillslope, ParWetland, ParCatchment, forcing, landscapes)
#      42 Fluxes_hillslope, States_hillslope = hillslope_func(t, ParHillslope, forcing, Fluxes_hillslope, States_hillslope)
#      44 # Wetland
# ---> 45 Fluxes_wetland, States_wetland, Ss = wetland_func(t, ParWetland, forcing, Fluxes_wetland, States_wetland, Ss, landscapes[2])
#      47 # Slow Reservoir
#      48 '''UPDATE'''
#
# Cell In[80], line 2, in wetland_func(timestep, Par, forcing, Fluxes, States, Ss, landscape_per)
#       1 #WETLANDS
# ----> 2 def wetland_func(timestep, Par, forcing, Fluxes, States, Ss, landscape_per):
#       3 	# HBVpareto Calculates values of 3 objective functions for HBV model
#       5 	I_max = Par[0]
#       6 	Ce = Par[1]
#
# KeyboardInterrupt:
